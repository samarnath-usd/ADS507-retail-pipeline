# %%
import pandas as pd
import mysql.connector

# Load CSV
df = pd.read_csv("sales_data.csv",encoding="latin1")

# %%
import sys
# !{sys.executable} -m pip install --upgrade mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\91970\appdata\local\programs\python\python310\lib\site-packages (8.0.32)
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.6.0-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Downloading mysql_connector_python-9.6.0-cp310-cp310-win_amd64.whl (16.5 MB)
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    -------- ------------------------------- 3.7/16.5 MB 21.8 MB/s eta 0:00:01
#    --------- ------------------------------ 3.9/16.5 MB 9.0 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.5 MB 8.6 MB/s eta 0:00:02
#    --------------- ------------------------ 6.6/16.5 MB 7.6 MB/s eta 0:00:02
#    ------------------- -------------------- 7.9/16.5 MB 7.5 MB/s eta 0:00:02
#    --------------------- ------------------ 8.9/16.5 MB 6.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.4/16.5 MB 6.5 MB/s eta 0:00:02
#    ------------------------- -------------- 10.5/16.5 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.1/16.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.5 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 13.9/16.5 MB 6.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.7/16.5 MB 5.8 MB/s eta 0:00:01
#    -------------------------------------- - 16.0/16.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.5/16.5 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: mysql-connector-python
#   Attempting uninstall: mysql-connector-python
#     Found existing installation: mysql-connector-python 8.0.32
#     Uninstalling mysql-connector-python-8.0.32:
#       Successfully uninstalled mysql-connector-python-8.0.32
# Successfully installed mysql-connector-python-9.6.0
# WARNING: Ignoring invalid distribution -ip (c:\users\91970\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\91970\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\users\91970\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
# Connect to MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root111",
    database="retail_pipeline"
)

cursor = conn.cursor()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Insert data
for _, row in df.iterrows():
    cursor.execute("""
        INSERT INTO raw_sales VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, tuple(row))

conn.commit()

print("Data loaded successfully!")
